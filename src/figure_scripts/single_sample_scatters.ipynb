# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
"C:\Users\donna\Downloads\Thesis\TSSClassification\results\03-28_12-14_ff_brca_high_var\excels\brca_full_bams--EE87812.hg38_corrected.bam_fragment_features.csv"

# %%
ff_data = pd.read_csv(r"/mnt/c/Users/donna/Downloads/Thesis/TSSClassification/results/03-28_12-14_ff_brca_high_var/excels/brca_full_bams--EE87812.hg38_corrected.bam_fragment_features.csv", usecols=['cov_x']).values.squeeze()
atac_data =  pd.read_csv('/mnt/c/Users/donna/Downloads/Thesis/brca_correlaties/TCGA_data/high_var_brca.csv', header=None).values

# %%
print(ff_data.shape)
print(atac_data.shape)
# Out:
# (1000,)
# (1000, 74)

# %%
selected_cols = np.random.choice(atac_data.shape[1], 3, replace=False)

for col in selected_cols:
    print(atac_data[:,col].shape)
    print(ff_data.shape)
    plt.scatter(atac_data[:,col], ff_data)
    plt.xlabel("Atac Peak")
    plt.ylabel("Coverage")
    plt.grid(True)
    plt.show()
# Out:
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
